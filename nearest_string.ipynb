# %%
from functools import partial
import time
# %run parse_instances.ipynb

# %%
def load_test(filename):
    with open(filename, "r") as file:
        lines = [line.strip() for line in file.readlines()]
    alphabet = lines[0]
    words = lines[1:]
    m = len(words[0])
    return alphabet, words, m

# %%
def hamming_distance(str1, str2):
    if len(str1) != len(str2):
        raise ValueError("Words must be of the same length")
    return sum(c1 != c2 for c1, c2 in zip(str1, str2))

# %%
def total_hamming_distance(target, words):
    return sum(list(map(partial(hamming_distance, target), words)))

# %%
def get_next_word(alphabet, m):
    if m == 0:
        yield ""
    else:
        for word in get_next_word(alphabet, m - 1):
            for letter in alphabet:
                yield word + letter

# %%
def find_nearest_string_brute_force(alphabet, words, m):
    nearest_string = None
    min_distance = float('inf')
    
    for candidate in get_next_word(alphabet, m):
        if candidate == "":
            break
        distance = total_hamming_distance(candidate, words)
        if distance < min_distance:
            min_distance = distance
            nearest_string = candidate
            
    return min_distance, nearest_string

# %%
def find_nearest_string_optimized(alphabet, words, n):
    return 0, ""

# %%
def generate_tests():
    tests_args = [
        { 'n': 5, 'm': 5, 'a': 'ABC', 'o': 'input1.txt' },
        { 'n': 5, 'm': 5, 'a': 'ABC', 'o': 'input2.txt' },
        { 'n': 5, 'm': 5, 'a': 'ABC', 'o': 'input3.txt' },
        { 'n': 5, 'm': 5, 'a': 'ABC', 'o': 'input4.txt' },
        { 'n': 5, 'm': 5, 'a': 'ABC', 'o': 'input5.txt' },
    ]
    for arg in tests_args:
        create_instance_file(arg['n'], arg['m'], arg['a'], output_file=arg['o'])
                                
    inputs = [load_test(filename) for filename in list(map(lambda x: x['o'], tests_args))]
    return inputs

# %%
def run_tests():
    tests = generate_tests()
    test_num = 1
    for alphabet, words, m in tests:
        print(f'=============== TEST {test_num} ===============\n\n')
        start_time = time.perf_counter()
        min_distance, nearest_string = find_nearest_string_brute_force(alphabet, words, m)
        end_time = time.perf_counter()
        execution_time = end_time - start_time

        print('\t-> Brute force:')
        print(f'\t- Nearest string: {nearest_string}')
        print(f'\t- Total Humming distance of the nearest string: {min_distance}')
        print(f'\t- Execution time: {execution_time:.4f}\n\n')

        start_time = time.perf_counter()
        min_distance, nearest_string = find_nearest_string_optimized(alphabet, words, m)
        end_time = time.perf_counter()
        execution_time = end_time - start_time
        
        print('\t-> Optimized algorithm:')
        print(f'\t- Nearest string: {nearest_string}')
        print(f'\t- Total Humming distance of the nearest string: {min_distance}')
        print(f'\t- Execution time: {execution_time:.4f}\n\n')
        
        test_num += 1

# %%
run_tests()
# Out:
# Instance generated:
#   n = 5
#   m = 5
#   alphabet = ABC
#   saved to: input1.txt
# Instance generated:
#   n = 5
#   m = 5
#   alphabet = ABC
#   saved to: input2.txt
# Instance generated:
#   n = 5
#   m = 5
#   alphabet = ABC
#   saved to: input3.txt
# Instance generated:
#   n = 5
#   m = 5
#   alphabet = ABC
#   saved to: input4.txt
# Instance generated:
#   n = 5
#   m = 5
#   alphabet = ABC
#   saved to: input5.txt
# =============== TEST 1 ===============
#
#
# 	-> Brute force:
# 	- Nearest string: BABCA
# 	- Total Humming distance of the nearest string: 12
# 	- Execution time: 0.0026
#
#
# 	-> Optimized algorithm:
# 	- Nearest string:
# 	- Total Humming distance of the nearest string: 0
# 	- Execution time: 0.0000
#
#
# =============== TEST 2 ===============
#
#
# 	-> Brute force:
# 	- Nearest string: BCCBC
# 	- Total Humming distance of the nearest string: 10
# 	- Execution time: 0.0027
#
#
# 	-> Optimized algorithm:
# 	- Nearest string:
# 	- Total Humming distance of the nearest string: 0
# 	- Execution time: 0.0000
#
#
# =============== TEST 3 ===============
#
#
# 	-> Brute force:
# 	- Nearest string: ABCCA
# 	- Total Humming distance of the nearest string: 9
# 	- Execution time: 0.0024
#
#
# 	-> Optimized algorithm:
# 	- Nearest string:
# 	- Total Humming distance of the nearest string: 0
# 	- Execution time: 0.0000
#
#
# =============== TEST 4 ===============
#
#
# 	-> Brute force:
# 	- Nearest string: CAACA
# 	- Total Humming distance of the nearest string: 12
# 	- Execution time: 0.0027
#
#
# 	-> Optimized algorithm:
# 	- Nearest string:
# 	- Total Humming distance of the nearest string: 0
# 	- Execution time: 0.0000
#
#
# =============== TEST 5 ===============
#
#
# 	-> Brute force:
# 	- Nearest string: ACCCA
# 	- Total Humming distance of the nearest string: 10
# 	- Execution time: 0.0025
#
#
# 	-> Optimized algorithm:
# 	- Nearest string:
# 	- Total Humming distance of the nearest string: 0
# 	- Execution time: 0.0000
