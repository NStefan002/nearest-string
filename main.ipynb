# %%
# %run test.ipynb

# %%
def main():
    run_tests()

# %%
if __name__ == "__main__":
    main()
# Out:
# |   Kategorija testa   |         Opis testa         |  |Σ|  |  n   |  m  |  BF dist  |  BF vreme  |  GA dist  |  GA vreme  |  VNS dist  |  VNS vreme  |
# |----------------------|----------------------------|-------|------|-----|-----------|------------|-----------|------------|------------|-------------|
# |      Trivijalni      |    Identični stringovi     |   3   |  10  |  5  |     0     |   0.002s   |     0     |   0.011s   |     0      |   0.092s    |
# |      Trivijalni      |        Jedan string        |   2   |  1   |  5  |     0     |   0.000s   |     0     |   0.003s   |     0      |   0.020s    |
# |   Granični slučaj    |     Binarni komplement     |   2   |  2   |  4  |     2     |   0.000s   |     2     |   0.003s   |     2      |   0.027s    |
# |   Granični slučaj    |      Kolonska većina       |   3   |  5   |  6  |     1     |   0.003s   |     1     |   0.009s   |     1      |   0.073s    |
# ...
