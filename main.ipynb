# %%
# %run test.ipynb

# %%
def main():
    run_tests()

# %%
if __name__ == "__main__":
    main()
# Out:
# =============== TEST [TRIVIAL] All Identical ===============
#
#
# -> Brute Force:
# 	- Nearest string: AAAAA
# 	- Max Humming distance: 0
# 	- Execution time: 0.0016
#
#
# -> GA Hybrid:
# 	- Nearest string: AAAAA
# 	- Max Humming distance: 0
# 	- Execution time: 0.0147
# 	- Result matches the Brute Force result
#
#
# -> VNS:
# 	- Nearest string: AAAAA
# 	- Max Humming distance: 0
# 	- Execution time: 0.0737
# 	- Result matches the Brute Force result
#
#
#
# =============== TEST [TRIVIAL] Single Word ===============
#
#
# -> Brute Force:
# 	- Nearest string: ABABA
# 	- Max Humming distance: 0
# 	- Execution time: 0.0001
#
#
# -> GA Hybrid:
# 	- Nearest string: ABABA
# 	- Max Humming distance: 0
# 	- Execution time: 0.0034
# 	- Result matches the Brute Force result
#
#
# -> VNS:
# 	- Nearest string: ABABA
# 	- Max Humming distance: 0
# 	- Execution time: 0.0211
# 	- Result matches the Brute Force result
#
#
#
# =============== TEST [TRIVIAL] m = 1 ===============
#
#
# ...
