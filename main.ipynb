# %%
# %run test.ipynb

# %%
def main():
    run_tests()

# %%
if __name__ == "__main__":
    main()
# Out:
# |   Kategorija testa   |               Opis testa               |  |Σ|  |  n   |  m  |  BF dist  |  BF vreme  |  GA dist  |  GA vreme  |  VNS dist  |  VNS vreme  |
# |----------------------|----------------------------------------|-------|------|-----|-----------|------------|-----------|------------|------------|-------------|
# |      Trivijalni      |        Svi stringovi identični         |   3   |  10  |  5  |     0     |   0.002s   |     0     |   0.012s   |     0      |   0.085s    |
# |      Trivijalni      |              Jedan string              |   2   |  1   |  5  |     0     |   0.000s   |     0     |   0.003s   |     0      |   0.022s    |
# |      Trivijalni      |          Dužina stringa m = 1          |   3   |  4   |  1  |     1     |   0.000s   |     1     |   0.000s   |     1      |   0.000s    |
# |   Granični slučaj    |           Binarni komplement           |   2   |  2   |  4  |     2     |   0.000s   |     2     |   0.003s   |     2      |   0.032s    |
# ...
