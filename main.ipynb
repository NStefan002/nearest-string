# %%
# %run test.ipynb

# %%
def main():
    run_tests()

# %%
if __name__ == "__main__":
    main()
# Out:
# Instance generated, saved to: input1.txt
# Instance generated, saved to: input2.txt
# Instance generated, saved to: input3.txt
# Instance generated, saved to: input4.txt
# Instance generated, saved to: input5.txt
#
# =============== TEST 1 ===============
#
#
# -> Brute force:
# 	- Nearest string: ACCAA
# 	- Max Humming distance: 3
# 	- Execution time: 0.0009
#
#
# -> GA Hybrid:
# 	- Nearest string: CCCBA
# 	- Max Humming distance: 3
# 	- Execution time: 0.0074
#
#
#
# =============== TEST 2 ===============
#
#
# -> Brute force:
# 	- Nearest string: AAAAB
# 	- Max Humming distance: 3
# 	- Execution time: 0.0009
#
#
# -> GA Hybrid:
# 	- Nearest string: ACACB
# 	- Max Humming distance: 3
# 	- Execution time: 0.0072
#
#
#
# =============== TEST 3 ===============
#
#
# -> Brute force:
# 	- Nearest string: AACAA
# 	- Max Humming distance: 3
# 	- Execution time: 0.0009
#
#
# -> GA Hybrid:
# 	- Nearest string: CCBBA
# 	- Max Humming distance: 3
# 	- Execution time: 0.0073
#
#
#
# ...
